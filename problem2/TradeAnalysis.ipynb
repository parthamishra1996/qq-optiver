# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
path = "/home/partha/Desktop/optiver/qq-optiver/problem2/historicalData/QQ4Data/"

# %%
stock_list = pd.read_csv(path + "stock_list.txt", header = None)
stock_list = stock_list[0]

# %%
stocks = {}
for x in stock_list:
    stocks[x] = pd.read_csv(path + x + ".csv")

# %%
#fig, axes = plt.subplots(nrows=2, ncols=7)
#n = 0
for x in stock_list:
    stocks[x].plot()#ax=axes[n/7,n%7]
    plt.savefig("Trend/"+x+".jpg")
    #n = n+1
